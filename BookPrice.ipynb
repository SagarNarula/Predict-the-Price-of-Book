# %%
import pandas as pd

# %%
train = pd.read_excel("Data_Train.xlsx")
test = pd.read_excel("Data_Test.xlsx")

# %%
train.tail(50)
# Out:
#                                                   Title  \
# 6187  You Are a Badass® Talking Button (Miniature Ed...
# 6188                              The Elements of Style
# 6189                         Slow Horses (Slough House)
# 6190  Tarzan: The Complete Russ Manning Newspaper St...
# 6191  Spy Secrets That Can Save Your Life: A Former ...
# 6192                                A Life in Diplomacy
# 6193         Justice League Vol. 1: Origin (The New 52)
# 6194                        English Grammar For Dummies
# 6195        Heart and Brain: An Awkward Yeti Collection
# 6196  While You Were Sleeping: A Gripping Psychologi...
# 6197     An Unquiet Mind: A memoir of moods and madness
# 6198                      How to Write Movie in 21 Days
# 6199  The Husband's Secret: From the bestselling aut...
# 6200  The Emperor Far Away: Travels At The Edge Of C...
# 6201  The Horse, the Wheel, and Language – How Bronz...
# 6202  Autobiography of a Yogi (Complete Paperback Ed...
# 6203                             Karukku Second Edition
# 6204  Plato and a Platypus Walk into a Bar . . .: Un...
# 6205                                      Deep Thinking
# 6206                         Spelling Success - Level 2
# 6207  A Shot at History: My Obsessive Journey to Oly...
# 6208                   Past Tense: A Jack Reacher Novel
# 6209  My Fight Your Fight: The Official Ronda Rousey...
# 6210                    Am I There Yet? (@bymariandrew)
# 6211                    Redemption (Amos Decker series)
# 6212                                 Sun and Moon Tarot
# 6213             Boys in Zinc (Penguin Modern Classics)
# 6214                                     The Abominable
# 6215                       Shikari Shambu 6: On the Run
# 6216     The Bridget Jones Omnibus: The Singleton Years
# 6217                    The Psychology Book (Big Ideas)
# 6218     Avatar: The Last Airbender - The Search Part 2
# 6219  Alice in Wonderland: The Graphic Novel (Campfi...
# 6220        Speed Mathematics: Do It Quick, Do It Right
# 6221                               The Room on the Roof
# 6222               India - Armenia: So Far Yet So Close
# 6223                          The Diary of a Young Girl
# 6224                     Asterix and the Goths: Album 3
# 6225           Dragon Masters #2: Saving the Sun Dragon
# 6226              Bhagwaan Ke Pakwaan: Food of the Gods
# 6227                 Architecture: Form, Space, & Order
# 6228                                   Capital Conquest
# 6229                                  A Legacy of Spies
# 6230                                      Corfu Trilogy
# 6231                                          Gone Girl
# 6232  Humans: A Brief History of How We F*cked It Al...
# 6233                                        The Chemist
# 6234  The Duke And I: Number 1 in series (Bridgerton...
# 6235                       Frostfire (Kanin Chronicles)
# 6236                        The First Order (Sam Capra)
#
#                                Author  \
# 6187                      Jen Sincero
# 6188  William Strunk Jr., E. B. White
# 6189                      Mick Herron
# 6190                     Russ Manning
# 6191                     Jason Hanson
# 6192         Maharajakrishna Rasgotra
# 6193                      Geoff Johns
# 6194                  Geraldine Woods
# 6195                 The Awkward Yeti
# 6196                    Kathryn Croft
# 6197             Kay Redfield Jamison
# 6198                        Viki King
# 6199                   Liane Moriarty
# 6200                      David Eimer
# 6201                 David W. Anthony
# 6202            Paramahansa Yogananda
# 6203                             Bama
# 6204                  Thomas Cathcart
# 6205                   Garry Kasparov
# 6206                Peter Clutterbuck
# 6207   Abhinav Bindra, Rohit Brijnath
# 6208                        Lee Child
# 6209                     Ronda Rousey
# 6210                      Mari Andrew
# 6211                   David Baldacci
# 6212                   Vanessa Decort
# 6213              Svetlana Alexievich
# 6214                      Dan Simmons
# 6215                 Rajani Thindiath
# 6216                   Helen Fielding
# 6217                             D.K.
# 6218                   Gene Luen Yang
# 6219                    Lewis Carroll
# 6220              Rajesh Kumar Thakur
# 6221                      Ruskin Bond
# 6222                   Achal Malhotra
# 6223                       Anne Frank
# 6224                    Albert Uderzo
# 6225                      Tracey West
# 6226                     Devang Singh
# 6227              Francis D. K. Ching
# 6228                       Saba Naqvi
# 6229                    John le Carré
# 6230                   Gerald Durrell
# 6231                    Gillian Flynn
# 6232                     Tom Phillips
# 6233                  Stephenie Meyer
# 6234                      Julia Quinn
# 6235                   Amanda Hocking
# 6236                      Jeff Abbott
#
#                                           Edition             Reviews  \
# 6187                      Paperback,– 22 Mar 2016  5.0 out of 5 stars
# 6188                      Paperback,– 23 Jul 1999  4.3 out of 5 stars
# 6189                      Paperback,– 11 Mar 2014  2.4 out of 5 stars
# 6190                      Hardcover,– 18 Jun 2013  5.0 out of 5 stars
# 6191                      Hardcover,– 22 Sep 2015  3.7 out of 5 stars
# 6192              Paperback,– Import, 15 Feb 2019  4.7 out of 5 stars
# 6193                       Paperback,– 5 Feb 2013  4.8 out of 5 stars
# 6194                      Paperback,– 20 Jun 2017  4.0 out of 5 stars
# 6195                      Paperback,– 20 Oct 2015  4.8 out of 5 stars
# 6196                      Paperback,– 16 Nov 2016  4.7 out of 5 stars
# 6197                       Paperback,– 1 Aug 2011  4.6 out of 5 stars
# 6198                      Paperback,– 15 Sep 1993  4.2 out of 5 stars
# 6199                      Paperback,– 29 Aug 2013  3.6 out of 5 stars
# 6200                      Paperback,– 14 Oct 2015  4.3 out of 5 stars
# 6201                       Paperback,– 3 Sep 2010  3.8 out of 5 stars
# 6202                       Paperback,– 9 Feb 1998  4.6 out of 5 stars
# 6203                      Paperback,– 14 Apr 2014  4.3 out of 5 stars
# 6204                      Paperback,– 24 Jun 2008  3.7 out of 5 stars
# 6205                       Hardcover,– 2 May 2017  4.3 out of 5 stars
# 6206                       Paperback,– 1 Jan 2007  4.6 out of 5 stars
# 6207                      Paperback,– 26 Jul 2017  4.9 out of 5 stars
# 6208  Mass Market Paperback,– Import, 30 Apr 2019  3.9 out of 5 stars
# 6209                       Paperback,– 3 Mar 2016  4.9 out of 5 stars
# 6210                      Hardcover,– 10 Jul 2018  3.3 out of 5 stars
# 6211                      Paperback,– 26 Apr 2019  4.0 out of 5 stars
# 6212                           Cards,– 5 Mar 2012  4.4 out of 5 stars
# 6213                       Paperback,– 2 Mar 2017  5.0 out of 5 stars
# 6214                         Paperback,– Jan 2014  1.0 out of 5 stars
# 6215                      Paperback,– 10 Jan 2016  4.7 out of 5 stars
# 6216                      Paperback,– 20 Jun 2013  4.4 out of 5 stars
# 6217                             Hardcover,– 2015  4.2 out of 5 stars
# 6218                      Paperback,– 23 Jul 2013  5.0 out of 5 stars
# 6219                      Paperback,– 27 Jul 2010  4.2 out of 5 stars
# 6220                      Paperback,– 20 Jul 2018  5.0 out of 5 stars
# 6221                       Paperback,– 1 Oct 2014  4.6 out of 5 stars
# 6222              Paperback,– Import, 13 Aug 2018  5.0 out of 5 stars
# 6223                             Paperback,– 2014  4.4 out of 5 stars
# 6224                      Paperback,– 21 Apr 2005  3.8 out of 5 stars
# 6225                      Paperback,– 14 May 2015  4.6 out of 5 stars
# 6226                       Paperback,– 4 Feb 2019  3.7 out of 5 stars
# 6227                      Paperback,– 14 Nov 2014  4.7 out of 5 stars
# 6228                      Hardcover,– 22 Apr 2015  3.3 out of 5 stars
# 6229                       Paperback,– 4 Oct 2017  4.1 out of 5 stars
# 6230                      Paperback,– 26 Sep 2006  4.9 out of 5 stars
# 6231                       Paperback,– 3 Jan 2013  4.1 out of 5 stars
# 6232                       Paperback,– 8 Aug 2018  5.0 out of 5 stars
# 6233                      Paperback,– 21 Nov 2016  3.3 out of 5 stars
# 6234                       Paperback,– 8 Jun 2006  3.8 out of 5 stars
# 6235                      Paperback,– 15 Jan 2015  3.5 out of 5 stars
# 6236                      Paperback,– 21 Dec 2016  3.9 out of 5 stars
#
#                      Ratings                                     Genre  \
# 6187       1 customer review  Personal Development & Self-Help (Books)
# 6188     74 customer reviews                    Writing Guides (Books)
# 6189      2 customer reviews         Crime, Thriller & Mystery (Books)
# 6190       1 customer review                       Anthologies (Books)
# 6191      6 customer reviews         Healthy Living & Wellness (Books)
# 6192     30 customer reviews     Biographies & Autobiographies (Books)
# 6193     24 customer reviews                   Comics & Mangas (Books)
# 6194       1 customer review                       Linguistics (Books)
# 6195     30 customer reviews                        Psychology (Books)
# 6196      4 customer reviews         Crime, Thriller & Mystery (Books)
# 6197      9 customer reviews                Action & Adventure (Books)
# 6198      3 customer reviews                    Writing Guides (Books)
# 6199     32 customer reviews                           Romance (Books)
# 6200      3 customer reviews                             Asian History
# 6201      3 customer reviews                       Linguistics (Books)
# 6202  1,416 customer reviews                          Hinduism (Books)
# 6203     12 customer reviews                             Asian History
# 6204     16 customer reviews                         History & Surveys
# 6205     29 customer reviews  Software & Business Applications (Books)
# 6206     96 customer reviews                  Exam Preparation (Books)
# 6207     73 customer reviews     Biographies & Autobiographies (Books)
# 6208     46 customer reviews                Action & Adventure (Books)
# 6209     10 customer reviews                      Martial Arts (Books)
# 6210      5 customer reviews  Arts History, Theory & Criticism (Books)
# 6211     12 customer reviews              Contemporary Fiction (Books)
# 6212      2 customer reviews                Mental & Spiritual Healing
# 6213      3 customer reviews                                  Cold War
# 6214       1 customer review                Action & Adventure (Books)
# 6215      4 customer reviews           Comics & Graphic Novels (Books)
# 6216      2 customer reviews                           Romance (Books)
# 6217     38 customer reviews     Biographies & Autobiographies (Books)
# 6218       1 customer review                   Comics & Mangas (Books)
# 6219     39 customer reviews                   Comics & Mangas (Books)
# 6220       1 customer review                                   Readers
# 6221    230 customer reviews              Literature & Fiction (Books)
# 6222      2 customer reviews                   International Relations
# 6223    902 customer reviews     Biographies & Autobiographies (Books)
# 6224      6 customer reviews                                    Mangas
# 6225      3 customer reviews                Action & Adventure (Books)
# 6226      8 customer reviews                            Food & Lodging
# 6227      7 customer reviews                      Architecture (Books)
# 6228     21 customer reviews                        Government (Books)
# 6229     29 customer reviews                Action & Adventure (Books)
# 6230     20 customer reviews                            Travel (Books)
# 6231    407 customer reviews                           Romance (Books)
# 6232      2 customer reviews                      Anthropology (Books)
# 6233      9 customer reviews              Contemporary Fiction (Books)
# 6234      3 customer reviews                           Romance (Books)
# 6235      4 customer reviews                Action & Adventure (Books)
# 6236      2 customer reviews                Action & Adventure (Books)
#
#                               BookCategory    Price
# 6187                                Humour   532.00
# 6188       Language, Linguistics & Writing   614.00
# 6189             Crime, Thriller & Mystery   651.00
# 6190                    Action & Adventure  3859.00
# 6191                              Politics   449.00
# 6192  Biographies, Diaries & True Accounts   409.00
# 6193                       Comics & Mangas   748.00
# 6194       Language, Linguistics & Writing  1107.00
# 6195                                Humour   790.00
# 6196             Crime, Thriller & Mystery   739.00
# 6197                    Action & Adventure   359.00
# 6198                                Humour   450.00
# 6199                               Romance   280.00
# 6200                              Politics   239.00
# 6201       Language, Linguistics & Writing  2033.00
# 6202  Biographies, Diaries & True Accounts   125.00
# 6203  Biographies, Diaries & True Accounts   299.00
# 6204                                Humour   413.00
# 6205                                Humour   999.44
# 6206       Language, Linguistics & Writing   132.00
# 6207                                Sports   288.00
# 6208                    Action & Adventure   563.00
# 6209                                Sports   578.88
# 6210  Biographies, Diaries & True Accounts   539.13
# 6211             Crime, Thriller & Mystery   479.00
# 6212                                Humour  1120.00
# 6213       Language, Linguistics & Writing   413.00
# 6214                    Action & Adventure   249.00
# 6215                       Comics & Mangas   115.00
# 6216                               Romance   245.00
# 6217  Biographies, Diaries & True Accounts   699.00
# 6218                       Comics & Mangas   549.00
# 6219                       Comics & Mangas   108.00
# 6220       Language, Linguistics & Writing   224.00
# 6221                              Politics   185.00
# 6222                              Politics   200.00
# 6223  Biographies, Diaries & True Accounts    59.00
# 6224                       Comics & Mangas   296.00
# 6225                    Action & Adventure   300.00
# 6226                                Humour   358.00
# 6227              Arts, Film & Photography  2729.00
# 6228                              Politics   175.00
# 6229                    Action & Adventure   295.00
# 6230  Biographies, Diaries & True Accounts   542.00
# 6231                               Romance   227.00
# 6232                                Humour   322.00
# 6233             Crime, Thriller & Mystery   421.00
# 6234                               Romance   399.00
# 6235                    Action & Adventure   319.00
# 6236                    Action & Adventure   452.00

# %%
## Removing Synopsis since here we are not going to use this feature

train = train[['Title', 'Author', 'Edition', 'Reviews', 'Ratings','Genre',
               'BookCategory', 'Price']]

test = test[['Title', 'Author', 'Edition', 'Reviews', 'Ratings','Genre',
               'BookCategory']]

# %%
train1=train.copy()

# %%
#A method to clean and restructure the Edition column
def split_edition(data):
    edition=list(data)
    ed_type = [i.split(",– ")[0].strip().upper() for i in edition]
    edit_date = [i.split(",– ")[1].strip() for i in edition]
    m_y = [i.split()[-2:] for i in edit_date]
    for i in range(len(m_y)):
        if len(m_y[i]) == 1:
            m_y[i].insert(0,'NA')
      
  # Based on the given dataset below is the list of possible values for Months
    months =  ['Apr','Aug','Dec','Feb', 'Jan', 'Jul','Jun','Mar','May','NA','Nov','Oct','Sep']
    ed_month = [m_y[i][0].upper() if m_y[i][0] in months else 'NA' for i in range(len(m_y))]
    ed_year = [int(m_y[i][1].strip()) if m_y[i][1].isdigit() else 0 for i in range(len(m_y))]
  
    return ed_type, ed_month, ed_year

# %%
#Identifying the maximum number of authors for a single book from the given datasets
authors_1 = list(train['Author'])
authors_2 = list(test['Author'])

authors_1.extend(authors_2)

authorslis = [i.split(",") for i in authors_1]
max = 1
for i in authorslis:
    if len(i) >= max:
        max = len(i)
print("Max. number of authors for a single boook = ",max)

for i in range(len(authorslis)):
    if len(authorslis[i]) == max:
        print(i)    
    
all_authors = [author.strip().upper() for listin in authorslis for author in listin]
# Out:
# Max. number of authors for a single boook =  7
# 7008

# %%
#Identifying the maximum number of Book Category for a single book from the given datasets
Book_category_1 = list(train['BookCategory'])
Book_category_2 = list(test['BookCategory'])

Book_category_1.extend(Book_category_2)

Book_category_lis = [i.split(",") for i in Book_category_1]
max = 1
for i in Book_category_lis:
    if len(i) >= max:
        max = len(i)
print("Max. number of Bookcategory for a single boook = ",max)
     
all_books_categories = [Book.strip().upper() for listin in Book_category_lis for Book in listin]
# Out:
# Max. number of Bookcategory for a single boook =  2

# %%
# A method to split the Author column in to 7 new columns
def split_authors(data):
    authors = list(data)
    A1 = []
    A2 = []
    A3 = []
    A4 = []
    A5 = []
    A6 = []
    A7 = []
    for i in authors:
        
        try :
            A1.append(i.split(',')[0].strip().upper())
        except :
            A1.append('NONE')
        try :
            A2.append(i.split(',')[1].strip().upper())
        except :
            A2.append('NONE')
        try :
            A3.append(i.split(',')[2].strip().upper())
        except :
            A3.append('NONE')
        try :
            A4.append(i.split(',')[3].strip().upper())
        except :
            A4.append('NONE')
        try :
            A5.append(i.split(',')[4].strip().upper())
        except :
            A5.append('NONE')
        try :
            A6.append(i.split(',')[5].strip().upper())
        except :
            A6.append('NONE')
        try :
            A7.append(i.split(',')[6].strip().upper())
        except :
            A7.append('NONE')

      
    return A1,A2,A3,A4,A5,A6,A7
  
all_authors.append('NONE')

# %%
# A method to split the Category column in to 2 new columns

def split_categories(data):
    cat = list(data)
  
    C1 = []
    C2 = []

    for i in cat:
        try :
            C1.append(i.split(',')[0].strip().upper())
        except :
            C1.append('NONE')
      
        try :
            C2.append(i.split(',')[1].strip().upper())
        except :
            C2.append('NONE')


      
    return C1,C2
  
all_books_categories.append('NONE')

# %%
#Identifying the maximum number of Genres for a single book from the given datasets

genre_1 = list(train['Genre'])
genre_2 = list(test['Genre'])

genre_1.extend(genre_2)

genre_lis = [i.split(",") for i in genre_1]


max = 1
for i in genre_lis:
    if len(i) >= max:
        max = len(i)
print("Max. number of genres for a single boook = ",max)
      
all_genres = [genre.strip().upper() for listin in genre_lis for genre in listin]
# Out:
# Max. number of genres for a single boook =  2

# %%
genre_lis
# Out:
# [['Action & Adventure (Books)'],
#  ['Cinema & Broadcast (Books)'],
#  ['International Relations'],
#  ['Contemporary Fiction (Books)'],
#  ['Photography Textbooks'],
#  ['Healthy Living & Wellness (Books)'],
#  ['Crime', ' Thriller & Mystery (Books)'],
#  ['Sports Training & Coaching (Books)'],
#  ['Biographies & Autobiographies (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Asian History'],
#  ['Banks & Banking'],
#  ['Action & Adventure (Books)'],
#  ['Asian History'],
#  ['Action & Adventure (Books)'],
#  ['Comics & Mangas (Books)'],
#  ["Children's Mysteries & Curiosities (Books)"],
#  ['Mangas'],
#  ['Biographies & Autobiographies (Books)'],
#  ['Artificial Intelligence'],
#  ['Action & Adventure (Books)'],
#  ['Biographies & Autobiographies (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Software & Business Applications (Books)'],
#  ['German'],
#  ['International Business'],
#  ['Cricket (Books)'],
#  ['Comics & Graphic Novels (Books)'],
#  ['PC & Video Games (Books)'],
#  ['Biographies & Autobiographies (Books)'],
#  ['Contemporary Fiction (Books)'],
#  ['Short Stories (Books)'],
#  ['Astrology'],
#  ['Romance (Books)'],
#  ['Design'],
#  ['Contemporary Fiction (Books)'],
#  ['Introductory & Beginning Programming'],
#  ['Travel (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Sports (Books)'],
#  ['Communications'],
#  ['Contemporary Fiction (Books)'],
#  ['Foreign Languages'],
#  ['Linguistics (Books)'],
#  ['Music Books'],
#  ['Outdoor Survival Skills (Books)'],
#  ['Music Books'],
#  ['True Accounts (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Mangas'],
#  ['Action & Adventure (Books)'],
#  ['Literature'],
#  ['Music Books'],
#  ['Action & Adventure (Books)'],
#  ['Biographies & Autobiographies (Books)'],
#  ['Society & Culture (Books)'],
#  ['Romance (Books)'],
#  ['Industries & Business Sectors (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Comics & Mangas (Books)'],
#  ['Programming Languages (Books)'],
#  ['Biographies & Autobiographies (Books)'],
#  ['Media Studies'],
#  ['Indian Writing (Books)'],
#  ['Networks & System Administration (Books)'],
#  ['Classic Fiction (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Cinema & Broadcast (Books)'],
#  ['Crime', ' Thriller & Mystery (Books)'],
#  ['Mangas'],
#  ['Dictionaries'],
#  ['Linguistics (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Comics & Mangas (Books)'],
#  ['Biographies & Autobiographies (Books)'],
#  ['Computer Hardware & Handheld Devices (Books)'],
#  ['Government (Books)'],
#  ['Arts History', ' Theory & Criticism (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Biographies & Autobiographies (Books)'],
#  ['Science & Mathematics'],
#  ['Biographies & Autobiographies (Books)'],
#  ['Hunting (Books)'],
#  ['Handicrafts', ' Decorative Arts & Crafts (Books)'],
#  ['Inflation'],
#  ['Healthy Living & Wellness (Books)'],
#  ['Religious & Spiritual Fiction (Books)'],
#  ['Law (Books)'],
#  ['Vocabulary Books'],
#  ['Asian History'],
#  ['Biographies & Autobiographies (Books)'],
#  ['Handicrafts', ' Decorative Arts & Crafts (Books)'],
#  ['Encyclopaedias & Reference Works (Books)'],
#  ['IT Certification Exams'],
#  ['Biographies & Autobiographies (Books)'],
#  ['Sign Language Reference'],
#  ['Engineering & Technology (Books)'],
#  ['Arts History', ' Theory & Criticism (Books)'],
#  ['Business Communication'],
#  ['IELTS'],
#  ['Indian Writing (Books)'],
#  ['Contemporary Fiction (Books)'],
#  ['Romance (Books)'],
#  ['Crime', ' Thriller & Mystery (Books)'],
#  ["Children's Adventure (Books)"],
#  ['Business Communication'],
#  ['Computer Hardware & Handheld Devices (Books)'],
#  ['Romance (Books)'],
#  ['Sports (Books)'],
#  ['Hinduism (Books)'],
#  ['Indian Writing (Books)'],
#  ['Biographies & Autobiographies (Books)'],
#  ['Mangas'],
#  ["Children's Games", ' Toys & Activities (Books)'],
#  ['Design'],
#  ['Healthy Living & Wellness (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Society & Culture (Books)'],
#  ['Comics & Graphic Novels (Books)'],
#  ['Design'],
#  ['Society & Culture (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Biographies & Autobiographies (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Dictionaries'],
#  ['Sports Training & Coaching (Books)'],
#  ['Government (Books)'],
#  ['Mangas'],
#  ['Political Theory (Books)'],
#  ['Industries & Business Sectors (Books)'],
#  ['Linguistics (Books)'],
#  ['Music Books'],
#  ['Investments & Securities'],
#  ["Children's Historical Fiction (Books)"],
#  ['Sustainable Development'],
#  ['Painting Textbooks'],
#  ['Economic Theory'],
#  ['Writing Guides (Books)'],
#  ['Business Communication'],
#  ['Budget Travel'],
#  ['Biotechnology Engineering Textbooks'],
#  ['Handicrafts', ' Decorative Arts & Crafts (Books)'],
#  ['Sales'],
#  ['Computing', ' Internet & Digital Media (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Illustrated Travel Books (Books)'],
#  ['Comics'],
#  ['Networks & System Administration (Books)'],
#  ['True Accounts (Books)'],
#  ['Computing', ' Internet & Digital Media (Books)'],
#  ['Crime', ' Thriller & Mystery (Books)'],
#  ['Programming Languages (Books)'],
#  ['Introductory & Beginning Programming'],
#  ['Contemporary Fiction (Books)'],
#  ['Agriculture & Farming (Books)'],
#  ['Government (Books)'],
#  ["Children's Crafts", ' Hobbies & Practical Interests (Books)'],
#  ['Comics & Mangas (Books)'],
#  ['Linguistics (Books)'],
#  ['Historical Fiction (Books)'],
#  ['Short Stories (Books)'],
#  ['Comics & Graphic Novels (Books)'],
#  ['Biographies & Autobiographies (Books)'],
#  ['Hinduism (Books)'],
#  ['Contemporary Fiction (Books)'],
#  ['Sports Training & Coaching (Books)'],
#  ['Language', ' Linguistics & Writing (Books)'],
#  ['Crime', ' Thriller & Mystery (Books)'],
#  ['Romance (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Biographies & Autobiographies (Books)'],
#  ['GRE'],
#  ['Mangas'],
#  ['Business Communication'],
#  ['Biographies & Autobiographies (Books)'],
#  ['Romance (Books)'],
#  ['Literature'],
#  ['Mangas'],
#  ['Contemporary Fiction (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Romance (Books)'],
#  ['Software & Business Applications (Books)'],
#  ['Language', ' Linguistics & Writing (Books)'],
#  ['Software & Business Applications (Books)'],
#  ['Travel (Books)'],
#  ['Introductory & Beginning Programming'],
#  ['Romance (Books)'],
#  ['Reincarnation'],
#  ['Public Policy'],
#  ['Romance (Books)'],
#  ["Children's Reference (Books)"],
#  ['Film & Television'],
#  ['Action & Adventure (Books)'],
#  ['Indian Writing (Books)'],
#  ['Crime', ' Thriller & Mystery (Books)'],
#  ['Anthologies (Books)'],
#  ['Design'],
#  ['Personal Development & Self-Help (Books)'],
#  ['Biographies & Autobiographies (Books)'],
#  ['Biographies & Autobiographies (Books)'],
#  ['Biographies & Autobiographies (Books)'],
#  ['Public Policy'],
#  ['Romance (Books)'],
#  ['Arts History', ' Theory & Criticism (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Mangas'],
#  ['Action & Adventure (Books)'],
#  ['True Accounts (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Comics & Graphic Novels (Books)'],
#  ['Economic Theory'],
#  ['Action & Adventure (Books)'],
#  ['Arts History', ' Theory & Criticism (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Industries & Business Sectors (Books)'],
#  ['Martial Arts (Books)'],
#  ['Mangas'],
#  ['Language', ' Linguistics & Writing (Books)'],
#  ['Action & Adventure (Books)'],
#  ['True Accounts (Books)'],
#  ['Crime', ' Thriller & Mystery (Books)'],
#  ['Industries & Business Sectors (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Dictionaries'],
#  ['Mangas'],
#  ['Language & Linguistics'],
#  ['Language', ' Linguistics & Writing (Books)'],
#  ['Action & Adventure (Books)'],
#  ['World African & Middle Eastern Literature'],
#  ['Crime', ' Thriller & Mystery (Books)'],
#  ['Design'],
#  ['Action & Adventure (Books)'],
#  ['Contemporary Fiction (Books)'],
#  ['Soccer (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Music Books'],
#  ['Cricket (Books)'],
#  ['Biographies & Autobiographies (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Grammar (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Comics & Mangas (Books)'],
#  ['Comics & Mangas (Books)'],
#  ['Short Stories (Books)'],
#  ['Mangas'],
#  ['Mangas'],
#  ['Biographies & Autobiographies (Books)'],
#  ['Comics & Mangas (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Mangas'],
#  ['Asian Literature'],
#  ['Action & Adventure (Books)'],
#  ['Essays (Books)'],
#  ['Travel (Books)'],
#  ['Short Stories (Books)'],
#  ['Writing Guides (Books)'],
#  ['TOEFL'],
#  ["Children's Adventure (Books)"],
#  ['American Literature'],
#  ['Sports Training & Coaching (Books)'],
#  ['GATE Exams'],
#  ['Indian Writing (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Language Learning & Teaching (Books)'],
#  ['Programming Languages (Books)'],
#  ['Healthy Living & Wellness (Books)'],
#  ['Martial Arts (Books)'],
#  ['Computing', ' Internet & Digital Media (Books)'],
#  ['Political Ideologies (Books)'],
#  ['Theater'],
#  ['Mind', ' Body & Spirit (Books)'],
#  ['Essays (Books)'],
#  ['Society & Culture (Books)'],
#  ['Earth Sciences Textbooks'],
#  ['Climbing & Mountaineering (Books)'],
#  ['Biographies & Autobiographies (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Language Learning & Teaching (Books)'],
#  ['Computing', ' Internet & Digital Media (Books)'],
#  ['Anthologies (Books)'],
#  ['Comics & Graphic Novels (Books)'],
#  ['Romance (Books)'],
#  ['Sports Training & Coaching (Books)'],
#  ['Photography Textbooks'],
#  ['Action & Adventure (Books)'],
#  ['Essays (Books)'],
#  ['Romance (Books)'],
#  ['Contemporary Fiction (Books)'],
#  ['Biographies & Autobiographies (Books)'],
#  ['Short Stories (Books)'],
#  ['Programming Algorithms'],
#  ['Biographies & Autobiographies (Books)'],
#  ['Horse Racing (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Games & Quizzes (Books)'],
#  ['Sports Training & Coaching (Books)'],
#  ['Family & Relationships (Books)'],
#  ['Martial Arts (Books)'],
#  ["Children's Crime & Thriller (Books)"],
#  ['Action & Adventure (Books)'],
#  ['Government (Books)'],
#  ['Biographies & Autobiographies (Books)'],
#  ['Romance (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Software & Business Applications (Books)'],
#  ['Vocabulary Books'],
#  ['Arts History', ' Theory & Criticism (Books)'],
#  ['Games & Quizzes (Books)'],
#  ['Linguistics (Books)'],
#  ['Comics & Mangas (Books)'],
#  ['Economics Books'],
#  ['Action & Adventure (Books)'],
#  ['Theatre & Spectacles (Books)'],
#  ['American Literature'],
#  ['Romance (Books)'],
#  ['Dictionaries'],
#  ['Political Theory (Books)'],
#  ['Architecture (Books)'],
#  ['Humour (Books)'],
#  ['Romance (Books)'],
#  ['Romance (Books)'],
#  ['Humour (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Crime', ' Thriller & Mystery (Books)'],
#  ['Romance (Books)'],
#  ['Romance (Books)'],
#  ['Comics & Mangas (Books)'],
#  ['Biographies & Autobiographies (Books)'],
#  ['Classic Fiction (Books)'],
#  ["Children's Humour (Books)"],
#  ['Crime', ' Thriller & Mystery (Books)'],
#  ['Earth Sciences Textbooks'],
#  ['Internet & Web (Books)'],
#  ['Comics & Mangas (Books)'],
#  ['Romance (Books)'],
#  ['Agriculture & Farming (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Handicrafts', ' Decorative Arts & Crafts (Books)'],
#  ['Government (Books)'],
#  ['Asian History'],
#  ['Action & Adventure (Books)'],
#  ['Horror (Books)'],
#  ['Biographies & Autobiographies (Books)'],
#  ['Networks & System Administration (Books)'],
#  ['Horror (Books)'],
#  ['Software & Business Applications (Books)'],
#  ['Contemporary Fiction (Books)'],
#  ['Fantasy', ' Science Fiction & Horror (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Programming & Software Development (Books)'],
#  ['Mangas'],
#  ['Algorithms'],
#  ['Travel (Books)'],
#  ["Children's Crafts", ' Hobbies & Practical Interests (Books)'],
#  ['Romance (Books)'],
#  ['Asian History'],
#  ['Horror (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Entrepreneurship'],
#  ['Romance (Books)'],
#  ['Industries & Business Sectors (Books)'],
#  ['Arts History', ' Theory & Criticism (Books)'],
#  ['Comics & Mangas (Books)'],
#  ['Government (Books)'],
#  ['Indian Writing (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Biographies & Autobiographies (Books)'],
#  ['Computer Security (Books)'],
#  ['Games & Quizzes (Books)'],
#  ['Romance (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Cinema & Broadcast (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Romance (Books)'],
#  ['Sports Training & Coaching (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Food', ' Drink & Entertaining (Books)'],
#  ['Crime', ' Thriller & Mystery (Books)'],
#  ['Cinema & Broadcast (Books)'],
#  ['Crime', ' Thriller & Mystery (Books)'],
#  ['Design'],
#  ['Mangas'],
#  ['Mangas'],
#  ['Engineering'],
#  ['Contemporary Fiction (Books)'],
#  ['Crime', ' Thriller & Mystery (Books)'],
#  ['Anthropology (Books)'],
#  ['Martial Arts (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Crime', ' Thriller & Mystery (Books)'],
#  ['History (Books)'],
#  ['Computer Science Books'],
#  ['Programming & Software Development (Books)'],
#  ['Action & Adventure (Books)'],
#  ['IGCSE'],
#  ['Comics & Graphic Novels (Books)'],
#  ['Biographies & Autobiographies (Books)'],
#  ['Earth Sciences Textbooks'],
#  ['Action & Adventure (Books)'],
#  ['Crime', ' Thriller & Mystery (Books)'],
#  ['Writing Guides (Books)'],
#  ['Architecture (Books)'],
#  ['Visual C++ Programming'],
#  ['Comics & Mangas (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Contemporary Fiction (Books)'],
#  ['Comics & Graphic Novels (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Language Learning & Teaching (Books)'],
#  ['Computer Security (Books)'],
#  ['Biographies & Autobiographies (Books)'],
#  ['Society & Culture (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Visual Arts'],
#  ['Photography Textbooks'],
#  ['Contemporary Fiction (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Comics & Graphic Novels (Books)'],
#  ['Comics & Mangas (Books)'],
#  ['Romance (Books)'],
#  ['Mangas'],
#  ['Action & Adventure (Books)'],
#  ['Comics & Mangas (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Mangas'],
#  ["Children's Fantasy (Books)"],
#  ["Children's Adventure (Books)"],
#  ['Romance (Books)'],
#  ['Romance (Books)'],
#  ['Mangas'],
#  ['Software Architecture'],
#  ['Fantasy', ' Science Fiction & Horror (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Teaching & Education'],
#  ['Indian Writing (Books)'],
#  ['Cricket (Books)'],
#  ['Contemporary Fiction (Books)'],
#  ['Romance (Books)'],
#  ['Crime', ' Thriller & Mystery (Books)'],
#  ['Industries & Business Sectors (Books)'],
#  ['Sports Training & Coaching (Books)'],
#  ['Romance (Books)'],
#  ['Networks & System Administration (Books)'],
#  ['Biographies & Autobiographies (Books)'],
#  ['Software Architecture'],
#  ['Arts History', ' Theory & Criticism (Books)'],
#  ['Cinema & Broadcast (Books)'],
#  ['Fantasy', ' Science Fiction & Horror (Books)'],
#  ['Romance (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Romance (Books)'],
#  ['Mangas'],
#  ['Comics'],
#  ['Crime', ' Thriller & Mystery (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Indian Writing (Books)'],
#  ['Computer Science Books'],
#  ['Design'],
#  ['Martial Arts (Books)'],
#  ['Political Ideologies (Books)'],
#  ['Family & Relationships (Books)'],
#  ['Humour (Books)'],
#  ['Romance (Books)'],
#  ['Contemporary Fiction (Books)'],
#  ['Action & Adventure (Books)'],
#  ['International Relations'],
#  ['Public Speaking Reference'],
#  ['Public Health'],
#  ['Action & Adventure (Books)'],
#  ['Language', ' Linguistics & Writing (Books)'],
#  ['Comics & Mangas (Books)'],
#  ['Crime', ' Thriller & Mystery (Books)'],
#  ['Language Learning & Teaching (Books)'],
#  ['Dictionaries'],
#  ['Networks & System Administration (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Biographies & Autobiographies (Books)'],
#  ['Crime', ' Thriller & Mystery (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Psychology (Books)'],
#  ['United States History'],
#  ['Dictionaries'],
#  ['Romance (Books)'],
#  ['Biographies & Autobiographies (Books)'],
#  ['Calculus'],
#  ['Government (Books)'],
#  ['Comics & Mangas (Books)'],
#  ['Engineering & Technology (Books)'],
#  ['Music Books'],
#  ['Comics & Mangas (Books)'],
#  ['Introductory & Beginning Programming'],
#  ['Political Parties (Books)'],
#  ['Family & Relationships (Books)'],
#  ["Children's Fantasy (Books)"],
#  ['Action & Adventure (Books)'],
#  ['Mangas'],
#  ['Handicrafts', ' Decorative Arts & Crafts (Books)'],
#  ['Action & Adventure (Books)'],
#  ['History (Books)'],
#  ['Arts History', ' Theory & Criticism (Books)'],
#  ['Comics & Mangas (Books)'],
#  ['Asian History'],
#  ['Music Books'],
#  ['Sports Training & Coaching (Books)'],
#  ['Writing Guides (Books)'],
#  ['Zoology'],
#  ['Comics & Mangas (Books)'],
#  ['Comics & Mangas (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Healthy Living & Wellness (Books)'],
#  ['Neuroscience'],
#  ['Gender Studies'],
#  ['Biographies & Autobiographies (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Language', ' Linguistics & Writing (Books)'],
#  ['General Dentistry'],
#  ['Indian Writing (Books)'],
#  ['Romance (Books)'],
#  ['Language', ' Linguistics & Writing (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Psychology (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Contemporary Fiction (Books)'],
#  ['Sports Training & Coaching (Books)'],
#  ['Mangas'],
#  ['Crime', ' Thriller & Mystery (Books)'],
#  ['Biographies & Autobiographies (Books)'],
#  ['History (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Action & Adventure (Books)'],
#  ["Children's Reference (Books)"],
#  ['Humour (Books)'],
#  ['Humour (Books)'],
#  ['Photography Textbooks'],
#  ['Short Stories (Books)'],
#  ['Romance (Books)'],
#  ['Political Ideologies (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Contemporary Fiction (Books)'],
#  ['Gender Studies'],
#  ['Action & Adventure (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Contemporary Fiction (Books)'],
#  ['Biographies & Autobiographies (Books)'],
#  ['Romance (Books)'],
#  ['Family & Relationships (Books)'],
#  ['Comics & Mangas (Books)'],
#  ['Comics'],
#  ['Martial Arts (Books)'],
#  ['Governmental'],
#  ['Biographies & Autobiographies (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Games & Quizzes (Books)'],
#  ['Language Learning & Teaching (Books)'],
#  ['Government (Books)'],
#  ['Comics & Mangas (Books)'],
#  ['True Accounts (Books)'],
#  ["Children's Crafts", ' Hobbies & Practical Interests (Books)'],
#  ['Romance (Books)'],
#  ['Asian History'],
#  ['Action & Adventure (Books)'],
#  ['Horror (Books)'],
#  ['Language Learning & Teaching (Books)'],
#  ['Algorithms'],
#  ['Action & Adventure (Books)'],
#  ['Action & Adventure (Books)'],
#  ['IELTS'],
#  ['Government (Books)'],
#  ['Economic History'],
#  ['Biographies & Autobiographies (Books)'],
#  ['Language Learning & Teaching (Books)'],
#  ['Handicrafts', ' Decorative Arts & Crafts (Books)'],
#  ['History of Slavery & Emancipation'],
#  ['Dictionaries'],
#  ['Economic Policy & Development'],
#  ['Astronomy (Books)'],
#  ['Ethics'],
#  ['Government (Books)'],
#  ['Asian History'],
#  ['Contemporary Fiction (Books)'],
#  ['French'],
#  ['Reincarnation'],
#  ['Action & Adventure (Books)'],
#  ['Historical Fiction (Books)'],
#  ['Computer Science Books'],
#  ['True Accounts (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Government (Books)'],
#  ['Design'],
#  ['Humour (Books)'],
#  ['Comics & Mangas (Books)'],
#  ['Comics & Mangas (Books)'],
#  ['Short Stories (Books)'],
#  ['Romance (Books)'],
#  ['Industries & Business Sectors (Books)'],
#  ['Music Books'],
#  ['Writing Guides (Books)'],
#  ['Comics & Mangas (Books)'],
#  ['Industries & Business Sectors (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Biographies & Autobiographies (Books)'],
#  ['Crime', ' Thriller & Mystery (Books)'],
#  ['Language Learning & Teaching (Books)'],
#  ['Romance (Books)'],
#  ['Industries & Business Sectors (Books)'],
#  ['Biographies & Autobiographies (Books)'],
#  ['Comics & Graphic Novels (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Software & Business Applications (Books)'],
#  ['International Relations & Globalization (Books)'],
#  ['Romance (Books)'],
#  ['Short Stories (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Japanese'],
#  ['Humour (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Software Design & Engineering'],
#  ['Comics & Mangas (Books)'],
#  ['Mangas'],
#  ['Biographies & Autobiographies (Books)'],
#  ['History & Surveys'],
#  ['Design'],
#  ['Short Stories (Books)'],
#  ['Comics & Mangas (Books)'],
#  ['Geography Textbooks'],
#  ['Writing Guides (Books)'],
#  ['Crafts', ' Home & Lifestyle (Books)'],
#  ['Mangas'],
#  ['Photography Textbooks'],
#  ['Action & Adventure (Books)'],
#  ['Political Parties (Books)'],
#  ['Photography Textbooks'],
#  ['Romance (Books)'],
#  ['Indian Writing (Books)'],
#  ['Romance (Books)'],
#  ['Computing', ' Internet & Digital Media (Books)'],
#  ['Linguistics (Books)'],
#  ['Comics & Mangas (Books)'],
#  ['Economics Textbooks'],
#  ['Comics & Mangas (Books)'],
#  ['Mangas'],
#  ['Romance (Books)'],
#  ['Handicrafts', ' Decorative Arts & Crafts (Books)'],
#  ["Children's Family", ' Personal & Social Issues (Books)'],
#  ['Contemporary Fiction (Books)'],
#  ['Crime', ' Thriller & Mystery (Books)'],
#  ['Sports Training & Coaching (Books)'],
#  ['Indian Writing (Books)'],
#  ['Gender Studies'],
#  ['Crime', ' Thriller & Mystery (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Psychology (Books)'],
#  ['Computer Science Books'],
#  ['Economic Policy & Development'],
#  ['Literature'],
#  ['Mangas'],
#  ['Crime', ' Thriller & Mystery (Books)'],
#  ['Writing Guides (Books)'],
#  ['Computer Databases (Books)'],
#  ['Hinduism (Books)'],
#  ['True Accounts (Books)'],
#  ['Ethics'],
#  ['Contemporary Fiction (Books)'],
#  ['True Accounts (Books)'],
#  ['Biographies & Autobiographies (Books)'],
#  ['Mangas'],
#  ["Children's Family", ' Personal & Social Issues (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Arts History', ' Theory & Criticism (Books)'],
#  ['Writing Guides (Books)'],
#  ['Biographies & Autobiographies (Books)'],
#  ['IELTS'],
#  ['Action & Adventure (Books)'],
#  ['Illustrated Travel Books (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Romance (Books)'],
#  ['Asian History'],
#  ['Programming & Software Development (Books)'],
#  ['Society & Culture (Books)'],
#  ['Language Learning & Teaching (Books)'],
#  ['Crime', ' Thriller & Mystery (Books)'],
#  ['Crime', ' Thriller & Mystery (Books)'],
#  ['Humour (Books)'],
#  ['Mathematics (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Political Freedom & Security (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Computer Science Books'],
#  ['Action & Adventure (Books)'],
#  ['Engineering Services Exams'],
#  ['Comics'],
#  ['Classic Fiction (Books)'],
#  ['Programming Languages (Books)'],
#  ['Biographies & Autobiographies (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Theatre & Spectacles (Books)'],
#  ['International Relations'],
#  ['Sporting Events & Organisations (Books)'],
#  ['Introductory & Beginning Programming'],
#  ['Humour (Books)'],
#  ['Engineering & Technology (Books)'],
#  ['Engineering & Technology (Books)'],
#  ['Outdoor Survival Skills (Books)'],
#  ["Children's Crafts", ' Hobbies & Practical Interests (Books)'],
#  ['Programming & Software Development (Books)'],
#  ['Theatre & Spectacles (Books)'],
#  ['Linguistics (Books)'],
#  ['Dictionaries'],
#  ['Action & Adventure (Books)'],
#  ['Software & Business Applications (Books)'],
#  ['Comics & Mangas (Books)'],
#  ['Introductory & Beginning Programming'],
#  ['Action & Adventure (Books)'],
#  ['Computer Science Books'],
#  ['Comics & Mangas (Books)'],
#  ['Crime', ' Thriller & Mystery (Books)'],
#  ['Biographies & Autobiographies (Books)'],
#  ["Children's Fantasy (Books)"],
#  ['Computing', ' Internet & Digital Media (Books)'],
#  ['Spirituality'],
#  ['Humour (Books)'],
#  ['Public Policy'],
#  ['Comics'],
#  ['Action & Adventure (Books)'],
#  ['Sports Training & Coaching (Books)'],
#  ['Public Policy'],
#  ['Language Learning & Teaching (Books)'],
#  ['Mangas'],
#  ['Romance (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Biographies & Autobiographies (Books)'],
#  ['Religious & Spiritual Fiction (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Biographies & Autobiographies (Books)'],
#  ['Mangas'],
#  ['Crime', ' Thriller & Mystery (Books)'],
#  ['Comics & Mangas (Books)'],
#  ['Romance (Books)'],
#  ["Children's Painting", ' Arts & Music (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Inflation'],
#  ['Cinema & Broadcast (Books)'],
#  ['Romance (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Mangas'],
#  ["Children's Reference (Books)"],
#  ['Language', ' Linguistics & Writing (Books)'],
#  ['Photography Textbooks'],
#  ['Romance (Books)'],
#  ['Hinduism (Books)'],
#  ['Introductory & Beginning Programming'],
#  ['Biographies & Autobiographies (Books)'],
#  ['Romance (Books)'],
#  ['Music Books'],
#  ['Music Books'],
#  ['Action & Adventure (Books)'],
#  ['Handicrafts', ' Decorative Arts & Crafts (Books)'],
#  ['Dictionaries'],
#  ['Action & Adventure (Books)'],
#  ['Essays (Books)'],
#  ['Martial Arts (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Government (Books)'],
#  ['Crime', ' Thriller & Mystery (Books)'],
#  ["Children's & Young Adult (Books)"],
#  ['Romance (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Biographies & Autobiographies (Books)'],
#  ['Crime', ' Thriller & Mystery (Books)'],
#  ['Crime', ' Thriller & Mystery (Books)'],
#  ['Games & Quizzes (Books)'],
#  ['Biographies & Autobiographies (Books)'],
#  ['Romance (Books)'],
#  ['Writing Guides (Books)'],
#  ['Humour (Books)'],
#  ['True Accounts (Books)'],
#  ['Music Books'],
#  ['Writing Guides (Books)'],
#  ['Theater'],
#  ['Language Learning & Teaching (Books)'],
#  ['Encyclopaedias & Reference Works (Books)'],
#  ['Crime', ' Thriller & Mystery (Books)'],
#  ['American Football (Books)'],
#  ['Cricket (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Industries & Business Sectors (Books)'],
#  ['Romance (Books)'],
#  ['Cinema & Broadcast (Books)'],
#  ['Biographies & Autobiographies (Books)'],
#  ['Rhetoric & Speech (Books)'],
#  ['Contemporary Fiction (Books)'],
#  ['Motorcycle Racing'],
#  ['Religious & Spiritual Fiction (Books)'],
#  ['Romance (Books)'],
#  ['Government (Books)'],
#  ['True Accounts (Books)'],
#  ['Introductory & Beginning Programming'],
#  ['Mangas'],
#  ['Study Guides'],
#  ['Biographies & Autobiographies (Books)'],
#  ['Mangas'],
#  ['Language & Linguistics'],
#  ['Mangas'],
#  ['Action & Adventure (Books)'],
#  ['Crime', ' Thriller & Mystery (Books)'],
#  ['Engineering & Technology (Books)'],
#  ['Historical Fiction (Books)'],
#  ['Romance (Books)'],
#  ['Crime', ' Thriller & Mystery (Books)'],
#  ['Romance (Books)'],
#  ['History (Books)'],
#  ['Grammar (Books)'],
#  ['Humour (Books)'],
#  ['Grammar (Books)'],
#  ['Romance (Books)'],
#  ['Mental & Spiritual Healing'],
#  ['Action & Adventure (Books)'],
#  ['Romance (Books)'],
#  ['Programming Languages (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Romance (Books)'],
#  ['Romance (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Romance (Books)'],
#  ['Business Communication'],
#  ['Essays (Books)'],
#  ['Handicrafts', ' Decorative Arts & Crafts (Books)'],
#  ['Cinema & Broadcast (Books)'],
#  ['Linguistics (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Programming Languages (Books)'],
#  ['Linguistics (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Contemporary Fiction (Books)'],
#  ['Sports Training & Coaching (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Biographies & Autobiographies (Books)'],
#  ['Design'],
#  ['Motorcycle Racing'],
#  ['Action & Adventure (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Romance (Books)'],
#  ['Earth Sciences Textbooks'],
#  ['Biographies & Autobiographies (Books)'],
#  ['Dictionaries'],
#  ['Photography Textbooks'],
#  ['Handicrafts', ' Decorative Arts & Crafts (Books)'],
#  ['Romance (Books)'],
#  ['Contemporary Fiction (Books)'],
#  ['Grammar (Books)'],
#  ['Romance (Books)'],
#  ['International Relations'],
#  ['Romance (Books)'],
#  ['IGCSE'],
#  ['Action & Adventure (Books)'],
#  ['Games & Quizzes (Books)'],
#  ['Networks & System Administration (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Grammar (Books)'],
#  ['Family & Relationships (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Sporting Events & Organisations (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Romance (Books)'],
#  ['Mangas'],
#  ['Action & Adventure (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Labor & Industrial Relations'],
#  ['Biographies & Autobiographies (Books)'],
#  ['Cinema & Broadcast (Books)'],
#  ['Martial Arts (Books)'],
#  ['Alternative Medicine (Books)'],
#  ['Action & Adventure (Books)'],
#  ['FPC'],
#  ['Arts History', ' Theory & Criticism (Books)'],
#  ['Contemporary Fiction (Books)'],
#  ['Python Programming'],
#  ['Economic History'],
#  ['Literature & Fiction (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Rhetoric & Speech (Books)'],
#  ['International Relations'],
#  ['Games & Quizzes (Books)'],
#  ['Crime', ' Thriller & Mystery (Books)'],
#  ['Horror (Books)'],
#  ['Programming & Software Development (Books)'],
#  ['Computer Databases (Books)'],
#  ['Horror (Books)'],
#  ['Language Learning & Teaching (Books)'],
#  ['History (Books)'],
#  ['Comics & Mangas (Books)'],
#  ['Writing Guides (Books)'],
#  ['Essays (Books)'],
#  ['Humour (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Romance (Books)'],
#  ['Contemporary Fiction (Books)'],
#  ['Horror (Books)'],
#  ['Contemporary Fiction (Books)'],
#  ['Music Books'],
#  ['Indian Writing (Books)'],
#  ['Theatre & Spectacles (Books)'],
#  ['Asian History'],
#  ['Computer Science Books'],
#  ['Essays (Books)'],
#  ['Comics & Mangas (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Writing Guides (Books)'],
#  ['Asian History'],
#  ['Design'],
#  ['Comics & Mangas (Books)'],
#  ['Classic Fiction (Books)'],
#  ['Biographies & Autobiographies (Books)'],
#  ["Children's Crafts", ' Hobbies & Practical Interests (Books)'],
#  ['Holocaust'],
#  ['Romance (Books)'],
#  ['Networks & System Administration (Books)'],
#  ['Romance (Books)'],
#  ['Handicrafts', ' Decorative Arts & Crafts (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Mangas'],
#  ['Encyclopedias for Children'],
#  ['Contemporary Fiction (Books)'],
#  ['Biographies & Autobiographies (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Handicrafts', ' Decorative Arts & Crafts (Books)'],
#  ['Design'],
#  ['Comics & Mangas (Books)'],
#  ['Romance (Books)'],
#  ['Politics (Books)'],
#  ['True Accounts (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Programming Languages (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Comics'],
#  ['Biographies', ' Diaries & True Accounts (Books)'],
#  ['Indian Writing (Books)'],
#  ['Literary Travel'],
#  ['Programming Languages (Books)'],
#  ["Children's Humour (Books)"],
#  ['Triathlon (Books)'],
#  ['Classic Fiction (Books)'],
#  ['Biographies & Autobiographies (Books)'],
#  ['Handicrafts', ' Decorative Arts & Crafts (Books)'],
#  ['Contemporary Fiction (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Biographies & Autobiographies (Books)'],
#  ['Encyclopaedias & Reference Works (Books)'],
#  ['Healthy Living & Wellness (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Travel & Holiday Guides (Books)'],
#  ['Handicrafts', ' Decorative Arts & Crafts (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Biographies & Autobiographies (Books)'],
#  ['Contemporary Fiction (Books)'],
#  ['Writing Guides (Books)'],
#  ['Theatre & Spectacles (Books)'],
#  ["Children's Picture Books (Books)"],
#  ['Crime', ' Thriller & Mystery (Books)'],
#  ['Society & Culture (Books)'],
#  ['Psychology (Books)'],
#  ['Hinduism (Books)'],
#  ['Travel with Pets'],
#  ["Children's Family", ' Personal & Social Issues (Books)'],
#  ['Dictionaries'],
#  ['Action & Adventure (Books)'],
#  ['Literature'],
#  ['Software Architecture'],
#  ['Reading Skills'],
#  ['Romance (Books)'],
#  ['Language', ' Linguistics & Writing (Books)'],
#  ['Action & Adventure (Books)'],
#  ['Language Learning & Teaching (Books)'],
#  ['Comics & Mangas (Books)'],
#  ["Children's Picture Books (Books)"],
#  ['Action & Adventure (Books)'],
#  ['Contemporary Fiction (Books)'],
#  ['Cinema & Broadcast (Books)'],
#  ...]

# %%
# A method to split the Genre column in to 7 new columns

def split_genres(data):
    genres = list(data)
  
    G1 = []
    G2 = []
  
    for i in genres:
        try :
            G1.append(i.split(',')[0].strip().upper())
      
        except :
            G1.append('NONE')
      
        try :
             G2.append(i.split(',')[1].strip().upper())
        except :
             G2.append('NONE')


      
    return G1,G2
  
all_genres.append('NONE')

# %%
# A method to clean and restructure the datasets

import re

def restructure(data):
     #Cleaning Title Column
    titles = list(data['Title'])
    titles = [title.strip().upper() for title in titles]
  
  #Cleaning & Restructuring Author Column
    a1,a2,a3,a4,a5,a6,a7 = split_authors(data['Author']) 
  
  #Cleaning & Restructuring Edition Column
    ed_type, ed_month, ed_year = split_edition(data['Edition'])
  
  #Cleaning Ratings Column
    ratings = list(data['Reviews'])
    ratings = [float(re.sub(" out of 5 stars", "", i).strip()) for i in ratings]
  
  #Cleaning Reviews Column
    reviews = list(data['Ratings'])
    plu = ' customer reviews'
    reviews = [re.sub(" customer reviews", "", i) if plu in i else re.sub(" customer review", "", i) for i in reviews  ]
    reviews = [int(re.sub(",", "", i).strip()) for i in reviews ]
  

  #Cleaning & Restructuring Genre Column
    g1, g2 = split_genres(data['Genre'])
  
  #Cleaning & Restructuring BookCategory Column
    c1,c2 = split_categories(data['BookCategory'])

  # Forming the Structured dataset
    structured_data = pd.DataFrame({'Title': titles,
                                  'Author1': a1,
                                  'Author2': a2,
                                  'Author3': a3,
                                  'Author4': a4,
                                  'Author5': a5,
                                  'Author6': a6,
                                  'Author7': a7,
                                  'Edition_Type': ed_type,
                                  'Edition_Month': ed_month,
                                  'Edition_Year': ed_year,
                                  'Ratings': ratings,
                                  'Reviews': reviews,
                                  'Genre1': g1,
                                  'Genre2': g2,
                                  'Category1': c1,
                                  'Category2': c2
                                  
                               })
  
    return structured_data

# %%
restructure(train).head(3)
# Out:
#                                  Title         Author1 Author2 Author3  \
# 0  THE PRISONER'S GOLD (THE HUNTERS 3)  CHRIS KUZNESKI    NONE    NONE
# 1   GURU DUTT: A TRAGEDY IN THREE ACTS    ARUN KHOPKAR    NONE    NONE
# 2         LEVIATHAN (PENGUIN CLASSICS)   THOMAS HOBBES    NONE    NONE
#
#   Author4 Author5 Author6 Author7 Edition_Type Edition_Month  Edition_Year  \
# 0    NONE    NONE    NONE    NONE    PAPERBACK           MAR          2016
# 1    NONE    NONE    NONE    NONE    PAPERBACK           NOV          2012
# 2    NONE    NONE    NONE    NONE    PAPERBACK           FEB          1982
#
#    Ratings  Reviews                      Genre1 Genre2           Category1  \
# 0      4.0        8  ACTION & ADVENTURE (BOOKS)   NONE  ACTION & ADVENTURE
# 1      3.9       14  CINEMA & BROADCAST (BOOKS)   NONE         BIOGRAPHIES
# 2      4.8        6     INTERNATIONAL RELATIONS   NONE              HUMOUR
#
#                  Category2
# 0                     NONE
# 1  DIARIES & TRUE ACCOUNTS
# 2                     NONE

# %%
X_train = restructure(train)

Y_train = train.iloc[:, -1].values

X_test = restructure(test)

# %%
X_train.head()
# Out:
#                                         Title          Author1 Author2  \
# 0         THE PRISONER'S GOLD (THE HUNTERS 3)   CHRIS KUZNESKI    NONE
# 1          GURU DUTT: A TRAGEDY IN THREE ACTS     ARUN KHOPKAR    NONE
# 2                LEVIATHAN (PENGUIN CLASSICS)    THOMAS HOBBES    NONE
# 3          A POCKET FULL OF RYE (MISS MARPLE)  AGATHA CHRISTIE    NONE
# 4  LIFE 70 YEARS OF EXTRAORDINARY PHOTOGRAPHY  EDITORS OF LIFE    NONE
#
#   Author3 Author4 Author5 Author6 Author7 Edition_Type Edition_Month  \
# 0    NONE    NONE    NONE    NONE    NONE    PAPERBACK           MAR
# 1    NONE    NONE    NONE    NONE    NONE    PAPERBACK           NOV
# 2    NONE    NONE    NONE    NONE    NONE    PAPERBACK           FEB
# 3    NONE    NONE    NONE    NONE    NONE    PAPERBACK           OCT
# 4    NONE    NONE    NONE    NONE    NONE    HARDCOVER           OCT
#
#    Edition_Year  Ratings  Reviews                        Genre1 Genre2  \
# 0          2016      4.0        8    ACTION & ADVENTURE (BOOKS)   NONE
# 1          2012      3.9       14    CINEMA & BROADCAST (BOOKS)   NONE
# 2          1982      4.8        6       INTERNATIONAL RELATIONS   NONE
# 3          2017      4.1       13  CONTEMPORARY FICTION (BOOKS)   NONE
# 4          2006      5.0        1         PHOTOGRAPHY TEXTBOOKS   NONE
#
#             Category1                Category2
# 0  ACTION & ADVENTURE                     NONE
# 1         BIOGRAPHIES  DIARIES & TRUE ACCOUNTS
# 2              HUMOUR                     NONE
# 3               CRIME       THRILLER & MYSTERY
# 4                ARTS       FILM & PHOTOGRAPHY

# %%
X_test.head()
# Out:
#                                                Title                 Author1  \
# 0         THE COMPLETE SHERLOCK HOLMES: 2 BOXES SETS  SIR ARTHUR CONAN DOYLE
# 1  LEARN DOCKER - FUNDAMENTALS OF DOCKER 18.X: EV...     GABRIEL N. SCHENKER
# 2                                           BIG GIRL          DANIELLE STEEL
# 3  THINK PYTHON: HOW TO THINK LIKE A COMPUTER SCI...         ALLEN B. DOWNEY
# 4  OXFORD WORD SKILLS: ADVANCED - IDIOMS & PHRASA...           REDMAN GAIRNS
#
#   Author2 Author3 Author4 Author5 Author6 Author7           Edition_Type  \
# 0    NONE    NONE    NONE    NONE    NONE    NONE  MASS MARKET PAPERBACK
# 1    NONE    NONE    NONE    NONE    NONE    NONE              PAPERBACK
# 2    NONE    NONE    NONE    NONE    NONE    NONE              PAPERBACK
# 3    NONE    NONE    NONE    NONE    NONE    NONE              PAPERBACK
# 4    NONE    NONE    NONE    NONE    NONE    NONE              PAPERBACK
#
#   Edition_Month  Edition_Year  Ratings  Reviews  \
# 0           OCT          1986      4.4      960
# 1           APR          2018      5.0        1
# 2           MAR          2011      5.0        4
# 3            NA          2016      4.1       11
# 4           DEC          2011      4.4        9
#
#                                        Genre1 Genre2  Category1  \
# 0                       SHORT STORIES (BOOKS)   NONE      CRIME
# 1                 OPERATING SYSTEMS TEXTBOOKS   NONE  COMPUTING
# 2                             ROMANCE (BOOKS)   NONE    ROMANCE
# 3  PROGRAMMING & SOFTWARE DEVELOPMENT (BOOKS)   NONE  COMPUTING
# 4                         LINGUISTICS (BOOKS)   NONE   LANGUAGE
#
#                   Category2
# 0        THRILLER & MYSTERY
# 1  INTERNET & DIGITAL MEDIA
# 2                      NONE
# 3  INTERNET & DIGITAL MEDIA
# 4     LINGUISTICS & WRITING

# %%
# A method for Finding Unique items for all columns
def unique_items(list1, list2):
    a = list1
    b = list2
    a.extend(b)
    return list(set(a))

# %%
from sklearn.preprocessing import LabelEncoder

le_Title = LabelEncoder()
all_titles = unique_items(list(X_train.Title),list(X_test.Title))
le_Title.fit(all_titles)

le_Edition_Type = LabelEncoder()
all_etypes = unique_items(list(X_train.Edition_Type),list(X_test.Edition_Type))
le_Edition_Type.fit(all_etypes)


le_Edition_Month = LabelEncoder()
all_em = unique_items(list(X_train.Edition_Month),list(X_test.Edition_Month))
le_Edition_Month.fit(all_em)

le_Author = LabelEncoder()
all_Authors = list(set(all_authors))
le_Author.fit(all_Authors)

le_Genre = LabelEncoder()
all_Genres = list(set(all_genres))
le_Genre.fit(all_Genres)

le_Category = LabelEncoder()
all_Categories = list(set(all_books_categories))
le_Category.fit(all_Categories)
# Out:
# LabelEncoder()

# %%
X_train['Title'] = le_Title.transform(X_train['Title'])

X_train['Edition_Type'] = le_Edition_Type.transform(X_train['Edition_Type'])



X_train['Edition_Month'] = le_Edition_Month.transform(X_train['Edition_Month'])

X_train['Author1'] = le_Author.transform(X_train['Author1'])
X_train['Author2'] = le_Author.transform(X_train['Author2'])
X_train['Author3'] = le_Author.transform(X_train['Author3'])
X_train['Author4'] = le_Author.transform(X_train['Author4'])
X_train['Author5'] = le_Author.transform(X_train['Author5'])
X_train['Author6'] = le_Author.transform(X_train['Author6'])
X_train['Author7'] = le_Author.transform(X_train['Author7'])


X_train['Genre1'] = le_Genre.transform(X_train['Genre1'])
X_train['Genre2'] = le_Genre.transform(X_train['Genre2'])


X_train['Category1'] = le_Category.transform(X_train['Category1'])
X_train['Category2'] = le_Category.transform(X_train['Category2'])

# %%
X_test['Title'] = le_Title.transform(X_test['Title'])

X_test['Edition_Type'] = le_Edition_Type.transform(X_test['Edition_Type'])



X_test['Edition_Month'] = le_Edition_Month.transform(X_test['Edition_Month'])

X_test['Author1'] = le_Author.transform(X_test['Author1'])
X_test['Author2'] = le_Author.transform(X_test['Author2'])
X_test['Author3'] = le_Author.transform(X_test['Author3'])
X_test['Author4'] = le_Author.transform(X_test['Author4'])
X_test['Author5'] = le_Author.transform(X_test['Author5'])
X_test['Author6'] = le_Author.transform(X_test['Author6'])
X_test['Author7'] = le_Author.transform(X_test['Author7'])


X_test['Genre1'] = le_Genre.transform(X_test['Genre1'])
X_test['Genre2'] = le_Genre.transform(X_test['Genre2'])


X_test['Category1'] = le_Category.transform(X_test['Category1'])
X_test['Category2'] = le_Category.transform(X_test['Category2'])

# %%
# Feature Scaling

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

X_train = sc.fit_transform(X_train)

X_test = sc.transform(X_test)

#Reshaping ti fit the scaler
Y_train = Y_train.reshape((len(Y_train), 1)) 

Y_train = sc.fit_transform(Y_train)

#Restoring the original shape after scaling
Y_train = Y_train.ravel()

# %%
from sklearn.model_selection import train_test_split

train_x, val_x, train_y, val_y = train_test_split(X_train, Y_train, test_size = 0.1, random_state = 123)

# %%
from xgboost import XGBRegressor
import numpy as np

xgb=XGBRegressor( objective='reg:squarederror', max_depth=6, learning_rate=0.1, n_estimators=100, booster = 'gbtree', n_jobs = -1,random_state = 1)
xgb.fit(train_x,train_y)

y_pred = sc.inverse_transform(xgb.predict(val_x))
y_true = sc.inverse_transform(val_y)

error = np.square(np.log10(y_pred +1) - np.log10(y_true +1)).mean() ** 0.5
score = 1 - error

print("RMLSE Score = ", score)
# Out:
# RMLSE Score =  0.7163958911417463

# %%
# Fitting the complete training set (inclusing val_x and val_y)
xgb.fit(X_train,Y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', learning_rate=0.1, max_delta_step=0,
#              max_depth=6, min_child_weight=1, missing=None, n_estimators=100,
#              n_jobs=-1, nthread=None, objective='reg:squarederror',
#              random_state=1, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#              seed=None, silent=None, subsample=1, verbosity=1)

# %%
# Predicting for test set
y_pred_xgb = sc.inverse_transform(xgb.predict(X_test))

# %%
# Saving the predictions in excel file

solution = pd.DataFrame(y_pred_xgb, columns = ['Price'])
solution.to_excel('Predict_Book_Price_Soln.xlsx', index = False)
